# %%
from Crypto.Util.number import long_to_bytes, bytes_to_long

# %%
p = [9671406556917033397931773,
9671406556917033398314601,
9671406556917033398439721,
9671406556917033398454847]

n = 8749002899132047699790752490331099938058737706735201354674975134719667510377522805717156720453193651

e = 65537

assert n == p[0] * p[1] * p[2] * p[3]

# %%
# Totient Value
tn = 1
for prime in p:
    tn *= prime-1
print(n)
# Out:
# 8749002899132047699790752490331099938058737706735201354674975134719667510377522805717156720453193651

# %%
# Private Exponent
d = pow(e, -1, tn)
print(d)
# Out:
# 1273429339988412698297205448652978641422672118523940510729640196484472358979449460334935735260841473

# %%
# Decryption
ct = 5834177939681309704189596065676685903729910303824560560929082759974421613450454803823195850471530486
pt = pow(ct, d, n)

# Redacted
#print(long_to_bytes(pt))
