# %%
from chall import encrypt_lfsr
from Crypto.Util.number import long_to_bytes

ct = bytes.fromhex("21c1b705764e4bfdafd01e0bfdbc38d5eadf92991cdd347064e37444e517d661cea9")

# %%
for i in range(256):
    ct_potential = long_to_bytes(encrypt_lfsr(ct, i))
    if b"picoCTF" in ct_potential:
        # Redacetd
        #print(ct_potential)
        pass
