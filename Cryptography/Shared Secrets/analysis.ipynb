# %%
from Crypto.Util.number import long_to_bytes
g = 2
p = 
A = 
b = 
enc = 0x3e272d210d1a08352a26113d7d2d3c7d3a1177797c2a2d77287d33

# %%
enc_b = long_to_bytes(enc)
print(enc_b)
# Out:
# b">'-!\r\x1a\x085*&\x11=}-<}:\x11wy|*-w(}3"

# %%
def xor(a, b):
    return bytes([x ^ y for x, y in zip(a,b)])
xor(b"picoCTF{", enc_b)
# Out:
# b'NNNNNNNN'

# %%
# Redacted
#print(xor(enc_b, b'N'*100))
